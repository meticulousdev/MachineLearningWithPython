# %%
import pandas as pd
data = pd.read_csv('../data/vote.csv', encoding='utf-8')
data.head()
# Out:
#    gender  region  edu  income  age  score_gov  score_progress  \
# 0       1       4    3       3    3          2               2
# 1       1       5    2       3    3          2               4
# 2       1       3    1       2    4          1               3
# 3       2       1    2       1    3          5               4
# 4       1       1    1       2    4          4               3
#
#    score_intention  vote  parties
# 0              4.0     1        2
# 1              3.0     0        3
# 2              2.8     1        4
# 3              2.6     1        1
# 4              2.4     1        1

# %%
X1 = data[['gender', 'region']]
XY = data[['edu', 'income', 'age', 'score_gov', 'score_progress', 'score_intention', 'vote', 'parties']]

# %%
X1['gender'] = X1['gender'].replace([1, 2], ['male', 'female'])
X1['region'] = X1['region'].replace([1, 2, 3, 4, 5], ['Sudo', 'Chungcheung', 'Honam', 'Youngnam', 'Others'])
# Out:
# /var/folders/rw/2hzjjgx52j57bvr5qsyw6kp80000gn/T/ipykernel_2672/3877965327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X1['gender'] = X1['gender'].replace([1, 2], ['male', 'female'])
# /var/folders/rw/2hzjjgx52j57bvr5qsyw6kp80000gn/T/ipykernel_2672/3877965327.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X1['region'] = X1['region'].replace([1, 2, 3, 4, 5], ['Sudo', 'Chungcheung', 'Honam', 'Youngnam', 'Others'])

# %%
print(X1.shape)
X1.head()
# Out:
# (211, 2)
#    gender    region
# 0    male  Youngnam
# 1    male    Others
# 2    male     Honam
# 3  female      Sudo
# 4    male      Sudo

# %%
X1_dum = pd.get_dummies(X1)
print(X1_dum.shape)
X1_dum.head()
# Out:
# (211, 7)
#    gender_female  gender_male  region_Chungcheung  region_Honam  \
# 0              0            1                   0             0
# 1              0            1                   0             0
# 2              0            1                   0             1
# 3              1            0                   0             0
# 4              0            1                   0             0
#
#    region_Others  region_Sudo  region_Youngnam
# 0              0            0                1
# 1              1            0                0
# 2              0            0                0
# 3              0            1                0
# 4              0            1                0
